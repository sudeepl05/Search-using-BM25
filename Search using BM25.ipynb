# %%
import pandas as pd
from rank_bm25 import *

# %%
df = pd.read_excel(r"C:\Users\vicinitas_search_results.xlsx")

# %%
df.head()
# Out:
#               Tweet Id                                               Text  \
# 0  1392083525222813698  RT @RishikaSadam : #Telangana’s #lockdown - Th...
# 1  1392083513717891076  RT @ChapalKhasnabis : Back to Geneva after an ...
# 2  1392083513671921664  RT @drsfaizanahmad : IMA filled FIR against  #...
# 3  1392083498509369345  RT @ipskabra : #COVID प्रोटोकॉल का पालन कर नव ...
# 4  1392083494168268801  RT @SonuJangraINC01 : #Covid सेंटर की सच्चाई आ...
#
#               Name      Screen Name                       UTC  \
# 0  Karam Komireddy        KaramKomi  2021-05-11T11:45:50.000Z
# 1       रवि रतलामी      raviratlami  2021-05-11T11:45:47.000Z
# 2      Wasim Akram  WasimAk62695513  2021-05-11T11:45:47.000Z
# 3   kanishka kumar   PrasharPrakash  2021-05-11T11:45:44.000Z
# 4       ज्ञानेंद्र  uQxI2z2YYWzwjl1  2021-05-11T11:45:43.000Z
#
#                        Created At  Favorites  Retweets Language  \
# 0  Tue May 11 11:45:50 +0000 2021          0         0       en
# ...

# %%
lst1 = df['Text'].to_list()

# %%
tokenized_corpus = [doc.split(" ") for doc in lst1]
tokenized_corpus
# Out:
# [['RT',
#   '@RishikaSadam',
#   ':',
#   '#Telangana’s',
#   '#lockdown',
#   '-',
#   'The',
#   'HC',
#   'directed',
#   'the',
#   'Govt',
#   'that',
#   'lockdown',
#   'should',
#   'not',
#   'come',
#   'in',
#   'the',
#   'way',
#   'of',
#   'citizens',
#   'who',
#   'are',
#   'due',
#   'for',
#   'their',
#   'second',
#   'dose',
#   'of',
#   '#Covid',
#   '#vaccination',
#   '#lockdowntelangana',
#   '@KaramKomi'],
#  ['RT',
#   '@ChapalKhasnabis',
#   ':',
#   'Back',
#   'to',
#   'Geneva',
#   'after',
#   'an',
#   'eventful',
#   'mission',
#   'in',
#   '#India.',
#   'Ensured',
#   'all',
#   'family',
#   'members',
#   'are',
#   'safe',
#   'and',
#   'vaccinated',
#   'during',
#   'current',
#   '#COVID',
#   'wave',
#   '#LifetimeExperience',
#   '#Heartbreaking',
#   'What',
#   'a',
#   'difference',
#   'between',
#   '#Geneva',
#   'and',
#   '#Kolkata',
#   '-',
#   'never',
#   'felt',
#   'so',
#   'helpless',
#   'in',
#   'my',
#   'life.',
# ...

# %%
bm25 = BM25Okapi(tokenized_corpus)

query = "vaccine" ## Enter search query
tokenized_query = query.split(" ")
print(tokenized_query)
# Out:
# ['vaccine']

# %%
doc_scores = bm25.get_scores(tokenized_query)
print(doc_scores)
# Out:
# [0.         0.         0.         ... 0.         3.19287543 0.        ]

# %%
docs = bm25.get_top_n(tokenized_query, lst1, n=5)
print(docs)
# Out:
# ['@MikeCarlton01 Re #ABC funding, looked up Budget Papers. After massive prior cuts, it got extra $4.7M in funding (.00044% far less than inflation).  \n\n#Morrison wastes $Ms on over-priced &amp; ineffective services eg useless #Covid app.; delivery vaccine #agedcare; consultancies vaccine roll-out..', "It's going to be a month after my #Covid recovery. Now I will go vaccine 😎😎😎😎", '@TonyHWindsor @barriecassidy @4corners @abc730 For its invaluable work, #ABC got extra $4.7M in  funding (.00044% far less than inflation).  \n\nWhile #Morrison Govt spends like drunken sailor on buying over-priced &amp; ineffective services from mates (eg useless #Covid app.; delivery vaccine #agedcare; vaccine roll-out) #auspol', 'RT @AlexBerenson : TL: DR - In the @pfizer teen #Covid vaccine trial, 4 or 5 (the exact figure is hidden) of 1,100 kids who got the vaccine had serious side effects, compared to 1 who got placebo.\n\n@US_FDA did not disclose specifics, so we have no idea what they were or if 
# ...

# %%
df_search = df[df['Text'].isin(docs)]

#df_search.drop(['Tweet Id', 'Screen Name', 'UTC', 'Created At','Favorites','Retweets','Language','Client','Tweet Type',], inplace=True, axis=1) #deleteing extra columns
df_search.drop(df.iloc[:, 3:19], inplace=True, axis=1) #deleteing extra columns

print("The search returned {} results.".format(len(df_search)-1))
df_search.head()
# Out:
# The search returned 5 results.
# c:\users\lahasu1\onedrive - novartis pharma ag\project\29. pk search\code\nlp\lib\site-packages\pandas\core\frame.py:4315: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                  Tweet Id                                               Text  \
# 229   1392082439078518787  @MikeCarlton01 Re #ABC funding, looked up Budg...
# 513   1392080885671817219  @TonyHWindsor @barriecassidy @4corners @abc730...
# 524   1392080830357393408  It's going to be a month after my #Covid recov...
# 1049  1392078033536765958  RT @pradeepkishan : What a despicable politici...
# 1398  1392076273170649092  RT @AlexBerenson : TL: DR - In the @pfizer tee...
#
#                  Name
# 229          MORRIGAN
# 513          MORRIGAN
# 524   Simi Elizabeth😃
# ...
